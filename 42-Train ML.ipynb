# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/DEMO-xgboost-dm'
# each region has its XGBoost container
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} 
my_region = boto3.session.Session().region_name # set the region of the instance
print("Great! - your SageMaker Instance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint to make inference requests.")
# Out:
# Great! - your SageMaker Instance is in the us-east-1 region. You will use the 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest container for your SageMaker endpoint to make inference requests.

# %%
# Download from your S3 bucket the census data CSV file based on the publically available census data from the ML repository curated by the University of California, Irvine
from io import StringIO
s3 = boto3.resource('s3')
bucket_name = 'train-census-earnings-xgboost' # place the adult_census.csv file in a bucket in your account
object_key = 'adult_census.csv'

# Load the data into a pandas dataframe 

csv_obj = s3.Object(bucket_name, object_key)
csv_string = csv_obj.get()['Body'].read().decode('utf-8')

raw_data = pd.read_csv(StringIO(csv_string))
raw_data.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          6   77516          1             13               3
# 1   50          2   83311          1             13               1
# 2   38          1  215646          4              9               2
# 3   53          1  234721          3              7               1
# 4   28          1  338409          1             13               1
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           9             4     1    2          2174             0
# 1           5             3     1    2             0             0
# 2           7             4     1    2             0             0
# 3           7             3     5    2             0             0
# 4           6             1     5    1             0             0
#
#    hours-per-week  native-country  y_no  y_yes
# 0              40               1     0      1
# 1              13               1     0      1
# 2              40               1     0      1
# 3              40               1     0      1
# 4              40              13     0      1

# %%
model_data = pd.get_dummies(raw_data)
model_data.head()

# %%
# Randomize the data and split it between train and test datasets on a 70% 30% split respectively
train_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (22792, 16) (9769, 16)

# %%
# Reformat the header and first column of the training data, 
# save the new train dataset to your S3 bucket as train.csv and load the data from the S3 bucket
pd.concat([train_data['y_yes'], train_data.drop(['y_no', 'y_yes'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
# Set up the SageMaker session, create an instance of the XGBoost model (an estimator), 
# and define the model’s hyperparameters
session_sm = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[my_region],role, train_instance_count=1, train_instance_type='ml.m4.xlarge',output_path='s3://{}/{}/output'.format(bucket_name, prefix),sagemaker_session=session_sm)
xgb.set_hyperparameters(alpha=1.4697769189147052,rate_drop=0.3,tweedie_variance_power=1.4,max_depth=3,eta=0.27735070284333196,min_child_weight=1.758169167129938,objective='binary:logistic',num_round=100)

# %%
# After the data is loaded and the XGBoost estimator is set up, 
# train the model using gradient optimization on a ml.m4.xlarge instance
xgb.fit({'train': s3_input_train})
# Out:
# 2020-02-06 18:41:08 Starting - Starting the training job...
# 2020-02-06 18:41:10 Starting - Launching requested ML instances......
# 2020-02-06 18:42:13 Starting - Preparing the instances for training......
# 2020-02-06 18:43:21 Downloading - Downloading input data...
# 2020-02-06 18:43:55 Training - Downloading the training image..Arguments: train
# [2020-02-06:18:44:15:INFO] Running standalone xgboost training.
# [2020-02-06:18:44:15:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-02-06:18:44:15:INFO] File size need to be processed in the node: 0.83mb. Available memory size in the node: 8513.19mb
# [2020-02-06:18:44:15:INFO] Determined delimiter of CSV input is ','
# [18:44:15] S3DistributionType set as FullyReplicated
# [18:44:15] 22792x14 matrix with 319088 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=6
# [0]#011train-auc:0.893345
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=6
# [1]#011train-auc:0.904018
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=6
# [2]#011train-auc:0.906286
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 16 pruned nodes, max_depth=6
# [3]#011train-auc:0.908695
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [4]#011train-auc:0.912723
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 16 pruned nodes, max_depth=6
# [5]#011train-auc:0.914918
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=6
# [6]#011train-auc:0.916547
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [7]#011train-auc:0.917992
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=6
# [8]#011train-auc:0.918658
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [9]#011train-auc:0.921067
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=6
# [10]#011train-auc:0.923189
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=6
# [11]#011train-auc:0.923938
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=6
# [12]#011train-auc:0.924823
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 16 pruned nodes, max_depth=6
# [13]#011train-auc:0.925322
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=6
# [14]#011train-auc:0.925698
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=6
# [15]#011train-auc:0.926922
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=6
# [16]#011train-auc:0.927523
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-auc:0.928112
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=6
# [18]#011train-auc:0.92862
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [19]#011train-auc:0.928664
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=6
# [20]#011train-auc:0.92925
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=6
# [21]#011train-auc:0.929858
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=6
# [22]#011train-auc:0.930553
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 36 pruned nodes, max_depth=6
# [23]#011train-auc:0.930967
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=6
# [24]#011train-auc:0.931419
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=6
# [25]#011train-auc:0.931701
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=6
# [26]#011train-auc:0.931942
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=6
# [27]#011train-auc:0.932473
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 30 pruned nodes, max_depth=6
# [28]#011train-auc:0.932843
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 38 pruned nodes, max_depth=6
# [29]#011train-auc:0.933144
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 62 pruned nodes, max_depth=6
# [30]#011train-auc:0.933472
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=6
# [31]#011train-auc:0.933687
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 42 pruned nodes, max_depth=3
# [32]#011train-auc:0.933748
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 42 pruned nodes, max_depth=6
# [33]#011train-auc:0.933973
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=6
# [34]#011train-auc:0.93408
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 18 pruned nodes, max_depth=3
# [35]#011train-auc:0.93423
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=6
# [36]#011train-auc:0.934536
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 24 pruned nodes, max_depth=5
# [37]#011train-auc:0.934636
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=6
# [38]#011train-auc:0.934824
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 40 pruned nodes, max_depth=6
# [39]#011train-auc:0.93515
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 36 pruned nodes, max_depth=4
# [40]#011train-auc:0.935407
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 24 pruned nodes, max_depth=3
# [41]#011train-auc:0.935533
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 38 pruned nodes, max_depth=6
# [42]#011train-auc:0.935785
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 40 pruned nodes, max_depth=6
# [43]#011train-auc:0.936058
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 34 pruned nodes, max_depth=6
# [44]#011train-auc:0.936282
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 36 pruned nodes, max_depth=0
# [45]#011train-auc:0.936282
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 38 pruned nodes, max_depth=4
# [46]#011train-auc:0.936342
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [47]#011train-auc:0.936467
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 52 pruned nodes, max_depth=5
# [48]#011train-auc:0.936571
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 32 pruned nodes, max_depth=5
# [49]#011train-auc:0.936622
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=6
# [50]#011train-auc:0.936731
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 42 pruned nodes, max_depth=6
# [51]#011train-auc:0.93698
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [52]#011train-auc:0.93698
# [18:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [53]#011train-auc:0.93698
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [54]#011train-auc:0.93698
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [55]#011train-auc:0.93698
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=5
# [56]#011train-auc:0.937343
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 20 pruned nodes, max_depth=2
# [57]#011train-auc:0.937407
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 24 pruned nodes, max_depth=5
# [58]#011train-auc:0.937417
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=5
# [59]#011train-auc:0.937549
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 30 pruned nodes, max_depth=6
# [60]#011train-auc:0.937824
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 60 pruned nodes, max_depth=3
# [61]#011train-auc:0.937903
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 32 pruned nodes, max_depth=6
# [62]#011train-auc:0.938105
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [63]#011train-auc:0.938105
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 58 pruned nodes, max_depth=5
# [64]#011train-auc:0.938246
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 36 pruned nodes, max_depth=0
# [65]#011train-auc:0.938246
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 72 pruned nodes, max_depth=0
# [66]#011train-auc:0.938246
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 24 pruned nodes, max_depth=6
# [67]#011train-auc:0.938311
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=6
# [68]#011train-auc:0.938435
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [69]#011train-auc:0.938435
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 42 pruned nodes, max_depth=6
# [70]#011train-auc:0.93861
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 38 pruned nodes, max_depth=4
# [71]#011train-auc:0.938672
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [72]#011train-auc:0.938672
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 68 pruned nodes, max_depth=4
# [73]#011train-auc:0.938758
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [74]#011train-auc:0.938758
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 48 pruned nodes, max_depth=6
# [75]#011train-auc:0.938918
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 46 pruned nodes, max_depth=4
# [76]#011train-auc:0.938955
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 40 pruned nodes, max_depth=4
# [77]#011train-auc:0.939052
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [78]#011train-auc:0.939098
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 36 pruned nodes, max_depth=5
# [79]#011train-auc:0.939177
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 78 pruned nodes, max_depth=0
# [80]#011train-auc:0.939177
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 48 pruned nodes, max_depth=3
# [81]#011train-auc:0.939189
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [82]#011train-auc:0.939189
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 28 pruned nodes, max_depth=5
# [83]#011train-auc:0.939241
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 44 pruned nodes, max_depth=4
# [84]#011train-auc:0.939325
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [85]#011train-auc:0.939362
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [86]#011train-auc:0.939362
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [87]#011train-auc:0.939362
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 24 pruned nodes, max_depth=3
# [88]#011train-auc:0.939473
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 64 pruned nodes, max_depth=0
# [89]#011train-auc:0.939473
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [90]#011train-auc:0.939473
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [91]#011train-auc:0.939473
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [92]#011train-auc:0.939473
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 48 pruned nodes, max_depth=4
# [93]#011train-auc:0.939558
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [94]#011train-auc:0.939558
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 38 pruned nodes, max_depth=4
# [95]#011train-auc:0.939581
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 28 pruned nodes, max_depth=6
# [96]#011train-auc:0.939761
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 38 pruned nodes, max_depth=4
# [97]#011train-auc:0.939802
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [98]#011train-auc:0.939802
# [18:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [99]#011train-auc:0.939802
# 2020-02-06 18:44:27 Uploading - Uploading generated training model
# 2020-02-06 18:44:27 Completed - Training job completed
# Training seconds: 66
# Billable seconds: 66

# %%
# Deploy your model and create an endpoint that you can access
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# -----------------!

# %%
# Predict whether census participants in the test dataset earned more than 50K
test_data_array = test_data.drop(['y_no', 'y_yes'], axis=1).values #load the data into an array
xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (9769,)

# %%
# Evaluate the performance and accuracy of the model
cm = pd.crosstab(index=test_data['y_yes'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted", "Under 50K", "Over 50K"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("Under 50K", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Over 50K", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
# Out:
# Overall Classification Rate: 87.2%
#
# Predicted      Under 50K      Over 50K
# Observed
# Under 50K      78% (1581)    10% (805)
# Over 50K        22% (442)     90% (6941)

# %%
# Terminate your SageMaker-related resources,
# delete the SageMaker endpoint and the objects in your S3 bucket
sagemaker.Session().delete_endpoint(xgb_predictor.endpoint)
# delete your bucket holding your training data and model artifacts
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '87E484C6598F7785',
#    'HostId': 'uG3t84pjqI3jMkbALlwbu5Y1gifYb3m6ni1wxNwJSNWiQK83qm+YW3zE1FIMzZSdvTsKTqyAD/k=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'uG3t84pjqI3jMkbALlwbu5Y1gifYb3m6ni1wxNwJSNWiQK83qm+YW3zE1FIMzZSdvTsKTqyAD/k=',
#     'x-amz-request-id': '87E484C6598F7785',
#     'date': 'Thu, 06 Feb 2020 18:55:06 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'adult_census_clean.csv'},
#    {'Key': 'sagemaker/DEMO-xgboost-dm/train/train.csv'},
#    {'Key': 'sagemaker/DEMO-xgboost-dm/output/xgboost-2020-02-06-18-41-08-669/output/model.tar.gz'}]}]
